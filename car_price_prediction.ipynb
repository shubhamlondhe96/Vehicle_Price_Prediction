# %% [markdown]
# <h1><center><font color='darkslategrey'>Vehicle Price Prediction</font> </center></h1>

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.getcwd()
# Out:
# 'C:\\Users\\Shubham\\Downloads'

# %% [markdown]
# ## EDA and Graphical Representation

# %%
dataset = pd.read_csv('dataset_car.csv')

# %%
dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
dataset.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
dataset.Owner.value_counts()
# Out:
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %%
car_name = dataset.Car_Name.to_list()

# %%
names = ['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
       's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
       '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
       'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
       'camry', 'land cruiser', 'Royal Enfield Thunder 500',
       'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
       'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
       'Royal Enfield Thunder 350', 'KTM 390 Duke ',
       'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
       'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
       'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
       'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
       'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
       'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
       'Yamaha FZ  v 2.0', 'Bajaj Pulsar  NS 200', 'Bajaj Pulsar 220 F',
       'TVS Apache RTR 180', 'Hero Passion X pro', 'Bajaj Pulsar NS 200',
       'Yamaha Fazer ', 'Honda Activa 4G', 'TVS Sport ',
       'Honda Dream Yuga ', 'Bajaj Avenger Street 220',
       'Hero Splender iSmart', 'Activa 3g', 'Hero Passion Pro',
       'Honda CB Trigger', 'Yamaha FZ S ', 'Bajaj Pulsar 135 LS',
       'Activa 4g', 'Honda CB Unicorn', 'Hero Honda CBZ extreme',
       'Honda Karizma', 'Honda Activa 125', 'TVS Jupyter',
       'Hero Honda Passion Pro', 'Hero Splender Plus', 'Honda CB Shine',
       'Bajaj Discover 100', 'Suzuki Access 125', 'TVS Wego',
       'Honda CB twister', 'Hero Glamour', 'Hero Super Splendor',
       'Bajaj Discover 125', 'Hero Hunk', 'Hero  Ignitor Disc',
       'Hero  CBZ Xtreme', 'Bajaj  ct 100', 'i20', 'grand i10', 'i10',
       'eon', 'xcent', 'elantra', 'creta', 'verna', 'city', 'brio',
       'amaze', 'jazz']

# %%
bike_list = ("Honda", "Bajaj","TVS","UM","Hero","Royal","Yamaha","KTM","Mahindra","Hyosung","Activa","Suzuki")
bike = [x for x in names if x.startswith(bike_list)]

# %%
car_list = [x for x in names if x not in bike]

# %%
dataset['Type'] = [1 if i in car_list else 0 for i in car_name]

# %%
dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Type
# 0      Dealer       Manual      0     1
# 1      Dealer       Manual      0     1
# 2      Dealer       Manual      0     1
# 3      Dealer       Manual      0     1
# 4      Dealer       Manual      0     1

# %%
sns.countplot(data=dataset, x = 'Type')

# %%
sns.catplot(data = dataset, x = 'Fuel_Type', y = 'Selling_Price', hue = 'Type')

# %%
sns.distplot(dataset['Selling_Price'], kde=True)

# %%
sns.boxplot(data=dataset, x = 'Selling_Price')

# %%
sns.boxplot(data=dataset, y = 'Kms_Driven')

# %%
sns.pairplot(data=dataset, hue="Transmission")
# Out:
# C:\Users\Shubham\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Shubham\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Shubham\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=dataset, hue="Seller_Type")
# Out:
# C:\Users\Shubham\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Shubham\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Shubham\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Shubham\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
sns.relplot(
    data=dataset,
    x="Present_Price", y="Selling_Price", col="Transmission",
    hue="Type")

# %%
final_dataset = dataset

# %%
final_dataset = dataset[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner','Type']]

# %%
final_dataset['Current Year']=2020

# %%
final_dataset['no_of_year']=final_dataset['Current Year']- final_dataset['Year']

# %%
final_dataset.drop(['Year','Current Year'],axis=1,inplace=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Type  no_of_year
# 0       Manual      0     1           6
# 1       Manual      0     1           7
# 2       Manual      0     1           3
# 3       Manual      0     1           9
# 4       Manual      0     1           6

# %%
final_dataset=pd.get_dummies(final_dataset, drop_first=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(final_dataset.corr(), annot=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Type  no_of_year  \
# 0           3.35           5.59       27000      0     1           6
# 1           4.75           9.54       43000      0     1           7
# 2           7.25           9.85        6900      0     1           3
# 3           2.85           4.15        5200      0     1           9
# 4           4.60           6.87       42450      0     1           6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
final_dataset.describe()
# Out:
#        Selling_Price  Present_Price     Kms_Driven       Owner        Type  \
# count     301.000000     301.000000     301.000000  301.000000  301.000000
# mean        4.661296       7.628472   36947.205980    0.043189    0.664452
# std         5.082812       8.644115   38886.883882    0.247915    0.472968
# min         0.100000       0.320000     500.000000    0.000000    0.000000
# 25%         0.900000       1.200000   15000.000000    0.000000    0.000000
# 50%         3.600000       6.400000   32000.000000    0.000000    1.000000
# 75%         6.000000       9.900000   48767.000000    0.000000    1.000000
# max        35.000000      92.600000  500000.000000    3.000000    1.000000
#
#        no_of_year  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# count  301.000000        301.000000        301.000000              301.000000
# mean     6.372093          0.199336          0.794020                0.352159
# ...

# %%
final_dataset.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'Type',
#        'no_of_year', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol',
#        'Seller_Type_Individual', 'Transmission_Manual'],
#       dtype='object')

# %% [markdown]
# ## Model Building

# %%
X=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state = 0)

# %% [markdown]
# ### Random forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
regressor=RandomForestRegressor().fit(x_train, y_train)
pred = regressor.predict(x_test)
r2 = r2_score(y_test, pred)
rmse =  mean_squared_error(y_test, pred,squared=False)
mae = mean_absolute_error(y_test, pred)
print(r2,rmse, mae)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-55d397d5c10c> in <module>
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
# ----> 3 regressor=RandomForestRegressor().fit(x_train, y_train)
#       4 pred = regressor.predict(x_test)
#       5 r2 = r2_score(y_test, pred)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

bootstrap = [True, False]
random_state = [0, 5, 10, 25, 50, 100, 101, 501]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'bootstrap' : bootstrap,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'random_state' : random_state}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'bootstrap': [True, False], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10], 'random_state': [0, 5, 10, 25, 50, 100, 101, 501]}

# %%
rf = RandomForestRegressor()
random_state = [0, 5, 10, 25, 50, 100, 101, 501]
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, random_state = 51, verbose=3, n_jobs = 1)

rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] random_state=5, n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, bootstrap=False
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  random_state=5, n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, bootstrap=False, score=-3.885, total=   1.0s
# [CV] random_state=5, n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, bootstrap=False
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  random_state=5, n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, bootstrap=False, score=-0.563, total=   1.3s
# [CV] random_state=5, n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, bootstrap=False
# ...

# %%
predictions=rf_random.predict(x_test)
predictions
# Out:
# array([ 7.15      ,  0.45      ,  4.625     ,  7.75      , 14.35643571,
#         5.31666667,  3.1       ,  0.465     ,  5.35      ,  4.86666667,
#         2.61666667,  0.85      ,  4.69410714,  6.71666667,  7.75      ,
#        15.625     ,  6.3       ,  4.03333333,  0.45      ,  1.7       ,
#         2.83333333,  4.76610714,  4.86666667,  9.83666667,  0.2       ,
#         0.75      ,  0.135     ,  0.435     ,  0.45      ,  3.9       ,
#         2.38333333,  5.725     ,  0.435     ,  8.9       ,  3.3       ,
#         1.2       ,  5.75      ,  5.125     ,  0.2       ,  9.9       ,
#         8.12      , 20.13928571,  4.697     ,  3.83333333,  6.2       ,
#        11.91666667,  0.25003571,  0.75      ,  5.05      ,  6.3       ,
#         4.86666667,  3.125     ,  5.05      , 23.        ,  1.13      ,
#         1.13      ,  0.29538571,  2.63333333,  3.675     ,  2.9       ,
#         3.43974286])

# %%
sns.distplot(y_test-predictions)

# %% [markdown]
# ### Model Performance and R- Square

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
print('R2:', metrics.r2_score(y_test, predictions))
# Out:
# MAE: 0.6390241217798579
# MSE: 1.066148688412326
# RMSE: 1.032544763393978
# R2: 0.957821923023671

# %% [markdown]
# ## Model Save

# %%
import joblib

# %%
joblib.dump(rf_random, 'random_forest.pkl')
# Out:
# ['random_forest.pkl']
